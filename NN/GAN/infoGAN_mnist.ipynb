# %%
# 本文该方法输入的cond只有一个，且输入范围为0-1，控制的为笔画粗细；
# 或需要其他要求，则输入多个cond，并让判别器输出还原，并进行损失优化，从而控制图片中的其他特征，如字体倾斜度等；
# infoGAN通过cond的引入，实现了对原始数据中不同隐藏特征的控制。

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import glob
import tensorflow.keras.datasets.mnist as mnist

# %%
# from numba import cuda
# cuda.select_device(0)
# cuda.close()

gpu = tf.config.experimental.list_physical_devices(device_type='GPU')
tf.config.experimental.set_memory_growth(gpu[0], True)

# %%
# 读取数据
(x_train,y_train),(x_test,_)=tf.keras.datasets.mnist.load_data()
print(x_train.shape,y_train.shape,x_train.dtype)

# 转换数据类型
x_train=((x_train.astype('float32')-127.5)/127.5).reshape(x_train.shape[0],28,28,1)
print(x_train.shape)

#  定义datasets
batch_szie=256
shuffle_size=x_train.shape[0]
noise_dim=30 # 输入G中的初始向量长度。
con_dim=30

datasets=tf.data.Dataset.from_tensor_slices((x_train,y_train)).shuffle(shuffle_size).batch(batch_szie)
datasets = datasets.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
# Dataset.prefetch() 方法，使得我们可以让数据集对象 Dataset 在训练时预取出若干个元素，
# 使得在 GPU 训练的同时 CPU 可以准备数据，从而提升训练流程的效率
# 使用方法和Dataset.batch() 、 Dataset.shuffle() 等非常类似
# Out:
# (60000, 28, 28) (60000,) uint8
# (60000, 28, 28, 1)

# %%
def generator_model():
    seed=layers.Input(shape=((noise_dim,)))
    con_seed=layers.Input(shape=((noise_dim,)))
    label=layers.Input(shape=(()))
    
    
    x=layers.Embedding(10,30,input_length=1)(label)  # 标签信息embeding,# x.shape=(batch_size,seq_len.embeddign),input_length为句子长度
    x=layers.Flatten()(x)  # x.shape=(batch_size,30*1)，30为embedding
    x=layers.concatenate([seed,con_seed,x])  # 将标签信息和数据信息、先验信息c融合
    
    x=layers.Dense(3*3*128,use_bias=False)(x)
    x=layers.Reshape((3,3,128))(x)
    x=layers.BatchNormalization()(x)
    x=layers.ReLU()(x)
    
    x=layers.Conv2DTranspose(64,(3,3),strides=(2,2),use_bias=False)(x) # (7,7,64)
    x=layers.BatchNormalization()(x)
    x=layers.ReLU()(x)  # 7*7
    
    x=layers.Conv2DTranspose(32,(3,3),strides=(2,2),
                             padding='same',use_bias=False)(x) # (14,14,32)
    x=layers.BatchNormalization()(x)
    x=layers.ReLU()(x)
    
    x=layers.Conv2DTranspose(1,(3,3),strides=(2,2),padding='same',
                             use_bias=False,activation='tanh')(x) # (28,28,1)
    
    model=tf.keras.Model(inputs=[seed,con_seed,label],outputs=x)
    
    return model


def discriminator_model():
    
    image=layers.Input(shape=((28,28,1)))
    
    x=layers.Conv2D(32,(3,3),strides=(2,2),padding='same',use_bias=False)(image)
    x=layers.BatchNormalization()(x)
    x=layers.LeakyReLU()(x)
    x=layers.Dropout(0.5)(x)
    
    x=layers.Conv2D(32*2,(3,3),strides=(2,2),padding='same',use_bias=False)(x)
    x=layers.BatchNormalization()(x)
    x=layers.LeakyReLU()(x)
    x=layers.Dropout(0.5)(x)
    
    x=layers.Conv2D(32*4,(3,3),strides=(2,2),padding='same',use_bias=False)(x)
    x=layers.BatchNormalization()(x)
    x=layers.LeakyReLU()(x)
    x=layers.Dropout(0.5)(x)
    
    x=layers.Flatten()(x)
    x1=layers.Dense(1)(x) # 真假判别向量
    x2=layers.Dense(10)(x) # 分类结果向量
    x3=layers.Dense(con_dim,activation='sigmoid')(x) # 条件输出
    
    model=tf.keras.Model(inputs=image,outputs=[x1,x2,x3])
    return model

# %%
# 损失
cross_entropy=tf.keras.losses.BinaryCrossentropy(from_logits=True)
category_cross_entropy=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True) # 多分类

def generator_loss(fake_out,fake_iamge_label_out,real_label,con_out,con_in):
    '''
    fake_imag: 生成图像的真假判断输出
    '''
    # 真假判断损失
    fake_loss=cross_entropy(tf.ones_like(fake_out),fake_out)
    # 分类判断损失
    cls_loss=category_cross_entropy(real_label,fake_iamge_label_out)
    # 隐藏编码损失
    con_loss=tf.reduce_mean(tf.square(con_out-con_in)) # c的输入和判别器中c的输出之间越相近越好
    return fake_loss+cls_loss+con_loss


def discriminator_loss(real_out,real_iamge_label_out,fake_out,real_label,con_out,con_in):
    '''
    real_out:对真实图片的真假判断输出
    real_iamge_label_out：判别器对真实图像的分类判断输出label，不一定是真的
    fake_out: 对生成图片的真假判断输出
    real_label: 指图像真实的label
    '''
    # 真假判断损失
    real_loss=cross_entropy(tf.ones_like(real_out),real_out)
    fake_loss=cross_entropy(tf.zeros_like(fake_out),fake_out)    
    # 分类判断损失
    cls_loss=category_cross_entropy(real_label,real_iamge_label_out)# 真实与判断label损失
    # 隐含编码/条件损失
    con_loss=tf.reduce_mean(tf.square(con_out-con_in)) # c的输入和判别器中c的输出之间越相近越好
    return real_loss+fake_loss+cls_loss+con_loss


# 优化器
generator_opti=tf.keras.optimizers.Adam(1e-4)
discriminator_opti=tf.keras.optimizers.Adam(1e-4)

# 参数
num = 10 # test的样本数
test_noise = tf.random.normal([num, noise_dim])
test_label = np.random.randint(0, 10, size=(num, 1)) # label，引导G生成的目标数据
print(test_label.T) # 查看test的标签

# 函数生成
generator=generator_model()
discriminator=discriminator_model()
# Out:
# [[2 9 0 9 7 4 7 6 9 0]]

# %%
tf.config.run_functions_eagerly(True)

@tf.function  # 函数修饰器,将用户定义的python风格的函数代码转化成高效的tensorflow计算图
                # 可以加速网络的推理速度,还能够有效降低占用显卡显存,使低显存的显卡也可以跑大网络
def train_step(images,labels):
    batchsize=labels.shape[0]
    noise=tf.random.normal([batchsize,noise_dim])
    cond_in=tf.random.uniform([batchsize,noise_dim])
    
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        gen_image=generator((noise,cond,labels),training=True)    # 输入噪声去生成图像并判别
        
        # 输出结果向量
        real_out,real_image_cls_out,_=discriminator(images,training=True) # 输入真实图像去判别
        fake_out,fake_image_cls_out,con_out=discriminator(gen_image,training=True) # 输入生成图像去判别
        
        # 输出计算的loss 
        gen_loss=generator_loss(fake_out,fake_image_cls_out,labels,con_out,cond_in)
        disc_loss=discriminator_loss(real_out,real_image_cls_out,fake_out,labels,
                                    con_out,cond_in)
        
    gradient_gen=gen_tape.gradient(gen_loss,generator.trainable_variables)
    gradient_disc=disc_tape.gradient(disc_loss,discriminator.trainable_variables)
    
    generator_opti.apply_gradients(zip(gradient_gen,generator.trainable_variables))
    discriminator_opti.apply_gradients(zip(gradient_disc,discriminator.trainable_variables))
    return gen_loss,disc_loss

# %%
def generator_plot_image(gen_model,test_noise,test_label,test_cond_int):  # 
    pred_images=gen_model((test_noise,test_cond_int,test_label),training=False) # 查看利用噪声数据生成出16的图像
    pred_images=tf.squeeze(pred_images)
    
    fig=plt.figure(figsize=(10,1))
    for i in range(pred_images.shape[0]):
        plt.subplot(1,10,i+1)
        plt.imshow((pred_images[i,:,:]+1)/2) # 画出利用噪声数据gen出的图像
        plt.axis('off')
    plt.show()

# %%
epoch_loss_avg_gen = tf.keras.metrics.Mean('g_loss')
epoch_loss_avg_disc = tf.keras.metrics.Mean('d_loss')
g_loss_results = []
d_loss_results = []

def train(dataset,epochs):
    for epoch in range(epochs):
        for image_batch ,label_batch in dataset:
            # 训练
            g_loss, d_loss = train_step(image_batch,label_batch)
            # 计算每个epoch的平均loss
            epoch_loss_avg_gen(g_loss)
            epoch_loss_avg_disc(d_loss)
            print('.',end='')
        # 记录每个epoch的loss
        g_loss_results.append(epoch_loss_avg_gen.result())
        d_loss_results.append(epoch_loss_avg_disc.result())
        
        epoch_loss_avg_gen.reset_states() # 将loss的buffer清除掉
        epoch_loss_avg_disc.reset_states()
        
        # 判断画图
        if epoch%5==0:
            # 画noise生成的图
            test_cond_in=tf.random.uniform([num,con_dim])
            generator_plot_image(generator,test_noise,test_label,test_cond_in)
        print('将开始第{}轮epoch'.format(epoch+1))
    
    # 将最后一次epoch的图画出
    test_cond_in=tf.random.uniform([num,con_dim])
    generator_plot_image(generator,test_noise,test_label,test_cond_in)

# %%
import time
result1=time.time()
epochs=100
train(datasets,epochs)
# [[1 3 2 6 4 6 3 6 6 7]]_noise_label
# 输出每轮训练时间
result2=time.time()
print('共训练了{}轮，每轮训练所用时间为{},总用时为{}'
      .format(epochs,(result2-result1)/(epochs),result2-result1))
# Out:
# ...........................................................................................................................................................................................................................................
# 将开始第1轮epoch
# ...........................................................................................................................................................................................................................................将开始第2轮epoch
# ...........................................................................................................................................................................................................................................将开始第3轮epoch
# ...........................................................................................................................................................................................................................................将开始第4轮epoch
# ...........................................................................................................................................................................................................................................将开始第5轮epoch
# ...........................................................................................................................................................................................................................................
# 将开始第6轮epoch
# ...........................................................................................................................................................................................................................................将开始第7轮epoch
# ...........................................................................................................................................................................................................................................将开始第8轮epoch
# ...........................................................................................................................................................................................................................................将开始第9轮epoch
# ...........................................................................................................................................................................................................................................将开始第10轮epoch
# ...........................................................................................................................................................................................................................................
# 将开始第11轮epoch
# ...........................................................................................................................................................................................................................................将开始第12轮epoch
# ...........................................................................................................................................................................................................................................将开始第13轮epoch
# ...........................................................................................................................................................................................................................................将开始第14轮epoch
# ...........................................................................................................................................................................................................................................将开始第15轮epoch
# ...........................................................................................................................................................................................................................................
# 将开始第16轮epoch
# ...........................................................................................................................................................................................................................................将开始第17轮epoch
# ...........................................................................................................................................................................................................................................将开始第18轮epoch
# ...........................................................................................................................................................................................................................................将开始第19轮epoch
# ...........................................................................................................................................................................................................................................将开始第20轮epoch
# ...........................................................................................................................................................................................................................................
# 将开始第21轮epoch
# ...........................................................................................................................................................................................................................................将开始第22轮epoch
# ...........................................................................................................................................................................................................................................将开始第23轮epoch
# ...........................................................................................................................................................................................................................................将开始第24轮epoch
# ...........................................................................................................................................................................................................................................将开始第25轮epoch
# ...........................................................................................................................................................................................................................................
# 将开始第26轮epoch
# ...........................................................................................................................................................................................................................................将开始第27轮epoch
# ...........................................................................................................................................................................................................................................将开始第28轮epoch
# ...........................................................................................................................................................................................................................................将开始第29轮epoch
# ...........................................................................................................................................................................................................................................将开始第30轮epoch
# ...........................................................................................................................................................................................................................................
# 将开始第31轮epoch
# ...........................................................................................................................................................................................................................................将开始第32轮epoch
# ...........................................................................................................................................................................................................................................将开始第33轮epoch
# ...........................................................................................................................................................................................................................................将开始第34轮epoch
# ...........................................................................................................................................................................................................................................将开始第35轮epoch
# ...........................................................................................................................................................................................................................................
# 将开始第36轮epoch
# ...........................................................................................................................................................................................................................................将开始第37轮epoch
# ...........................................................................................................................................................................................................................................将开始第38轮epoch
# ...........................................................................................................................................................................................................................................将开始第39轮epoch
# ...........................................................................................................................................................................................................................................将开始第40轮epoch
# ...........................................................................................................................................................................................................................................
# 将开始第41轮epoch
# ...........................................................................................................................................................................................................................................将开始第42轮epoch
# ...........................................................................................................................................................................................................................................将开始第43轮epoch
# ...........................................................................................................................................................................................................................................将开始第44轮epoch
# ...........................................................................................................................................................................................................................................将开始第45轮epoch
# ...........................................................................................................................................................................................................................................
# 将开始第46轮epoch
# ...........................................................................................................................................................................................................................................将开始第47轮epoch
# ...........................................................................................................................................................................................................................................将开始第48轮epoch
# ...........................................................................................................................................................................................................................................将开始第49轮epoch
# ...........................................................................................................................................................................................................................................将开始第50轮epoch
# ...........................................................................................................................................................................................................................................
# 将开始第51轮epoch
# ...........................................................................................................................................................................................................................................将开始第52轮epoch
# ...........................................................................................................................................................................................................................................将开始第53轮epoch
# ...........................................................................................................................................................................................................................................将开始第54轮epoch
# ...........................................................................................................................................................................................................................................将开始第55轮epoch
# ...........................................................................................................................................................................................................................................
# 将开始第56轮epoch
# ...........................................................................................................................................................................................................................................将开始第57轮epoch
# ...........................................................................................................................................................................................................................................将开始第58轮epoch
# ...........................................................................................................................................................................................................................................将开始第59轮epoch
# ...........................................................................................................................................................................................................................................将开始第60轮epoch
# ...........................................................................................................................................................................................................................................
# 将开始第61轮epoch
# .....................................................................................................................................................................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <module>
#       2 result1=time.time()
#       3 epochs=100
# ----> 4 train(datasets,epochs)
#       5 # [[1 3 2 6 4 6 3 6 6 7]]_noise_label
#       6 # 输出每轮训练时间
#       7 result2=time.time()
#
# Input In [8], in train(dataset, epochs)
#       7 for epoch in range(epochs):
#       8     for image_batch ,label_batch in dataset:
#       9         # 训练
# ---> 10         g_loss, d_loss = train_step(image_batch,label_batch)
#      11         # 计算每个epoch的平均loss
#      12         epoch_loss_avg_gen(g_loss)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\tensorflow\python\eager\def_function.py:892, in Function.__call__(self, *args, **kwds)
#     890 if self._run_functions_eagerly:
#     891   with trace.Trace(self._name, tf_function_call="eager"):
# --> 892     return self._python_function(*args, **kwds)
#     894 # Only count the statistics the first time, before initialization took
#     895 # place.
#     896 if self._created_variables is None:
#
# Input In [6], in train_step(images, labels)
#      22 gradient_gen=gen_tape.gradient(gen_loss,generator.trainable_variables)
#      23 gradient_disc=disc_tape.gradient(disc_loss,discriminator.trainable_variables)
# ---> 25 generator_opti.apply_gradients(zip(gradient_gen,generator.trainable_variables))
#      26 discriminator_opti.apply_gradients(zip(gradient_disc,discriminator.trainable_variables))
#      27 return gen_loss,disc_loss
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:678, in OptimizerV2.apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     675   grads_and_vars = self._aggregate_gradients(grads_and_vars)
#     676 grads_and_vars = self._transform_gradients(grads_and_vars)
# --> 678 return tf.__internal__.distribute.interim.maybe_merge_call(
#     679     functools.partial(self._distributed_apply, apply_state=apply_state),
#     680     strategy,
#     681     grads_and_vars,
#     682     name=name)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\tensorflow\python\distribute\merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribution_strategy_context.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:723, in OptimizerV2._distributed_apply(self, distribution, grads_and_vars, apply_state, name)
#     719 with distribution.extended.colocate_vars_with(var):
#     720   with name_scope_only_in_function_or_graph(
#     721       "update" if eagerly_outside_functions else "update_" +
#     722       var.op.name):
# --> 723     update_op = distribution.extended.update(
#     724         var, apply_grad_to_update_var, args=(grad,), group=False)
#     725     if tf.distribute.in_cross_replica_context():
#     726       # In cross-replica context, extended.update returns a list of
#     727       # update ops from all replicas (group=False).
#     728       update_ops.extend(update_op)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2630, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    2627   fn = autograph.tf_convert(
#    2628       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    2629   with self._container_strategy().scope():
# -> 2630     return self._update(var, fn, args, kwargs, group)
#    2631 else:
#    2632   return self._replica_ctx_update(
#    2633       var, fn, args=args, kwargs=kwargs, group=group)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3703, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    3700 def _update(self, var, fn, args, kwargs, group):
#    3701   # The implementations of _update() and _update_non_slot() are identical
#    3702   # except _update() passes `var` as the first argument to `fn()`.
# -> 3703   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3709, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    3705 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    3706   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    3707   # once that value is used for something.
#    3708   with UpdateContext(colocate_with):
# -> 3709     result = fn(*args, **kwargs)
#    3710     if should_group:
#    3711       return result
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\tensorflow\python\autograph\impl\api.py:595, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     593 def wrapper(*args, **kwargs):
#     594   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 595     return func(*args, **kwargs)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:701, in OptimizerV2._distributed_apply.<locals>.apply_grad_to_update_var(var, grad)
#     699   if "apply_state" in self._sparse_apply_args:
#     700     apply_kwargs["apply_state"] = apply_state
# --> 701   return self._resource_apply_sparse_duplicate_indices(
#     702       grad.values, var, grad.indices, **apply_kwargs)
#     704 if "apply_state" in self._dense_apply_args:
#     705   apply_kwargs["apply_state"] = apply_state
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:1324, in OptimizerV2._resource_apply_sparse_duplicate_indices(self, grad, handle, indices, **kwargs)
#    1301 def _resource_apply_sparse_duplicate_indices(self, grad, handle, indices,
#    1302                                              **kwargs):
#    1303   """Add ops to apply sparse gradients to `handle`, with repeated indices.
#    1304
#    1305   Optimizers which override this method must deal with repeated indices. See
#    (...)
#    1322     An `Operation` which updates the value of the variable.
#    1323   """
# -> 1324   summed_grad, unique_indices = _deduplicate_indexed_slices(
#    1325       values=grad, indices=indices)
#    1326   return self._resource_apply_sparse(summed_grad, handle, unique_indices,
#    1327                                      **kwargs)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\keras\optimizers\optimizer_v2\optimizer_v2.py:58, in _deduplicate_indexed_slices(values, indices)
#      45 def _deduplicate_indexed_slices(values, indices):
#      46   """Sums `values` associated with any non-unique `indices`.
#      47
#      48   Args:
#    (...)
#      56     `values` slices associated with each unique index.
#      57   """
# ---> 58   unique_indices, new_index_positions = tf.unique(indices)
#      59   summed_values = tf.math.unsorted_segment_sum(
#      60       values, new_index_positions,
#      61       tf.shape(unique_indices)[0])
#      62   return (summed_values, unique_indices)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\tensorflow\python\util\dispatch.py:1082, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1080 # Fallback dispatch system (dispatch v1):
#    1081 try:
# -> 1082   return dispatch_target(*args, **kwargs)
#    1083 except (TypeError, ValueError):
#    1084   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1085   # TypeError, when given unexpected types.  So we need to catch both.
#    1086   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\tensorflow\python\ops\array_ops.py:2067, in unique(x, out_idx, name)
#    2028 """Finds unique elements in a 1-D tensor.
#    2029
#    2030 See also `tf.unique_with_counts`.
#    (...)
#    2061
#    2062 """
#    2063 # TODO(yongtang): switch to v2 once API deprecation
#    2064 # period (3 weeks) pass.
#    2065 # TODO(yongtang): The documentation should also
#    2066 # be updated when switch  to v2.
# -> 2067 return gen_array_ops.unique(x, out_idx, name)
#
# File D:\editor\pythonProject\pythonProject1\venv\lib\site-packages\tensorflow\python\ops\gen_array_ops.py:11953, in unique(x, out_idx, name)
#   11951 if tld.is_eager:
#   11952   try:
# > 11953     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#   11954       _ctx, "Unique", name, x, "out_idx", out_idx)
#   11955     _result = _UniqueOutput._make(_result)
#   11956     return _result
#
# KeyboardInterrupt:

# %%
plt.plot(range(1, len(g_loss_results)+1), g_loss_results, label='g_loss')
plt.plot(range(1, len(d_loss_results)+1), d_loss_results, label='d_loss')
plt.legend()

# %%
# 保存模型
generator.save('gen_model/generate_infogan.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # test

# %%
noise_dim = 30 # 输入G中的初始向量长度。
num = 10 # test的样本数
test_noise = tf.random.normal([num, noise_dim])
test_label = np.array([9]*10) # label，引导G生成的目标数据
test_cond_in = tf.convert_to_tensor(np.linspace(0, 1, 300).reshape(num, noise_dim)) # c1变量，控制粗细
print(test_label.transpose()) # 查看test的标签

generator_plot_image(generator,test_noise,test_label,test_cond_in)
# Out:
# [9 9 9 9 9 9 9 9 9 9]
